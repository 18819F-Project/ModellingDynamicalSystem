# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1) = plt.subplots(figsize=(6,6))

ax1.plot([14.4150,14.1706,14.0317,14.0986,14.0605,13.9103,13.9659,14.0196,14.0264,13.7185,13.5322,13.9324,13.5029,13.5949,13.8084,13.0796,13.3079,13.1323,13.2479,13.4365], "-ob", label="With Classical LDNN layer")
ax1.plot([22.7903,22.3159,21.7140,21.1633,20.3756,19.5159,18.9726,18.3601,17.7374,17.3627,16.9054,17.0605,16.5187,16.1044,16.0684,15.4410,16.0848,15.1804,14.9939,14.8628], "-or", label="With Hybrid LDNN Classical-Quantum layer")
ax1.plot([0.0853,0.0896,0.0905,0.0855,0.0885,0.0818,0.0800,0.0806,0.0991,0.0817,0.0815,0.0854,0.0839,0.0774,0.0862,0.0804,0.0781,0.0768,0.0786,0.0744], "-og", label="With Hybrid LDNN Quantum-Classical-Quantum layer")

ax1.set_ylabel("Loss")
ax1.set_ylim([0, 25])
ax1.set_xlabel("Epoch (Iteration)")
ax1.legend(loc=3, prop = {'size': 10})
